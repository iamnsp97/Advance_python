# %%
my_list=[1,2,3,4]
my_list
# Out:
# [1, 2, 3, 4]

# %%
print(my_list)
type(my_list)
# Out:
# [1, 2, 3, 4]
# list

# %%
new_list=['Shreyash',35,97,'o',True]

# %%
print(new_list)
# Out:
# ['Shreyash', 35, 97, 'o', True]

# %%
print(len(new_list))
print(len(my_list))
# Out:
# 5
# 4

# %%
print(new_list[0])
print(my_list[0])
# Out:
# Shreyash
# 1

# %%
print(my_list[1:4])
# Out:
# [2, 3, 4]

# %%
print(new_list)
print(new_list[1:])
# Out:
# ['Shreyash', 35, 97, 'o', True]
# [35, 97, 'o', True]

# %%
print(new_list)
print(new_list[:3])
# Out:
# ['Shreyash', 35, 97, 'o', True]
# ['Shreyash', 35, 97]

# %%
print(new_list[-4:])
# Out:
# [35, 97, 'o', True]

# %%
print(new_list +["Sarap"])
new_list
# Out:
# ['Shreyash', 35, 97, 'o', True, 'Sarap']
# ['Shreyash', 35, 97, 'o', True]

# %%
new_list+= ["Xyz"]
new_list
# Out:
# ['Shreyash', 35, 97, 'o', True, 'Xyz']

# %%
min(my_list)
# Out:
# 1

# %%
max(my_list)
# Out:
# 4

# %%
sum(my_list)
# Out:
# 10

# %%
my_list1=['a','z','c','A','Y','Z','B']
sorted(my_list1)
# Out:
# ['A', 'B', 'Y', 'Z', 'a', 'c', 'z']

# %%
sorted(my_list, reverse=True)
# Out:
# [4, 3, 2, 1]

# %%
my_list.append('Append ')

# %%
my_list
# Out:
# [1, 2, 3, 4, 'Append ']

# %%
len(my_list)
# Out:
# 5

# %%
my_list.append(97.7)
my_list
# Out:
# [1, 2, 3, 4, 'Append ', 97.7, 97.7]

# %%
my_list.append([1,4,7])
my_list
# Out:
# [1,
#  2,
#  3,
#  4,
#  'Append ',
#  97.7,
#  97.7,
#  [1, 4, 7],
#  [1, 4, 7],
#  [1, 4, 7],
#  [1, 4, 7],
#  [1, 4, 7]]

# %%
my_list.pop(-2)
# Out:
# 97.7

# %%
my_list
# Out:
# [1, 2, 3, 4, 'Append ', 97.7, [1, 4, 7]]

# %%
my_list[-1][-2]
# Out:
# 4

# %%
my_list
# Out:
# [1, 2, 3, 4, 'Append ', 97.7, [1, 4, 7]]

# %%
my_list.remove([1,4,7])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-1fcdf903817c> in <module>
# ----> 1 my_list.remove([1,4,7])
#       2 my_list
#
# ValueError: list.remove(x): x not in list

# %%
my_list
# Out:
# [1, 2, 3, 4, 'Append ', 97.7]

# %%
len(my_list)
# Out:
# 6

# %%
trial_list=[19,3,5,7,12]
trial_list
# Out:
# [19, 3, 5, 7, 12]

# %%
trial_list.clear()
trial_list
# Out:
# []

# %%
trial_list
# Out:
# []

# %%
trial_list=[5,2,8,3,7,34,1,"aabbcc","xyavc",5,3,2]
print(trial_list)
trial_list.count(2)
# Out:
# [5, 2, 8, 3, 7, 34, 1, 'aabbcc', 'xyavc', 5, 3, 2]
# 2

# %%
trial_list.index(34)
# Out:
# 0

# %%
trial_list.index("aabbcc")
# Out:
# 7

# %%
trial_list.remove("xyavc")
trial_list
# Out:
# [1, 2, 3, 5, 7, 8, 34, 5, 3, 2]

# %%
trial_list.sort()
trial_list
# Out:
# [1, 2, 2, 3, 3, 5, 5, 7, 8, 34]

# %%
trial_list.sort(reverse=True)
trial_list
# Out:
# [34, 8, 7, 5, 5, 3, 3, 2, 2, 1]

# %%
boolean_list=[True,False]
boolean_list
# Out:
# [True, False]

# %%
boolean_list.sort(reverse=False)
boolean_list
# Out:
# [False, True]

# %%
list1=[1,2,3,4]
list2=['a','b','c']
list3=[10,9,8,7]
list4=[list1,list2,list3]
list4
# Out:
# [[1, 2, 3, 4], ['a', 'b', 'c'], [10, 9, 8, 7]]

# %%
list1.index(4)
# Out:
# 3

# %%
list4[-2][-2]
# Out:
# 'b'

# %%
list4[2][2]
# Out:
# 8
