# %%
first_string="Shreyash"
first_string
# Out:
# 'Shreyash'

# %%
phrase="Hello this is Shreyash, practicing on Strings"
print(phrase)
type(phrase)
# Out:
# Hello this is Shreyash, practicing on Strings
# str

# %%
sentence="I'm a Data Analyst"
sentence
# Out:
# "I'm a Data Analyst"

# %%
hash="#"
print(hash)
type(hash)
# Out:
# #
# str

# %%
"Printing a string"
# Out:
# 'Printing a string'

# %%
print("hello this \n is Shreyash ")
print("\nI'm very fond of exploring new technologies")
print("I like to work \non new programming languages")
# Out:
# hello this
#  is Shreyash
#
# I'm very fond of exploring new technologies
# I like to work
# on new programming languages

# %%
statement="Count my length"
len(statement)
# Out:
# 15

# %%
statement="Central Board Of Secondary Eductaion "
print(len(statement))
print(statement)
print(statement[5:20])
print(statement[5])
print(statement[35])
print(statement[-3])

print(statement*3)

print(statement.lower())
print(statement.upper())
print(statement.count(' '))
print(statement.replace(' ','_'))
"Central" in statement
# Out:
# 37
# Central Board Of Secondary Eductaion
# al Board Of Sec
# a
# n
# o
# Central Board Of Secondary Eductaion Central Board Of Secondary Eductaion Central Board Of Secondary Eductaion
# central board of secondary eductaion
# CENTRAL BOARD OF SECONDARY EDUCTAION
# 5
# Central_Board_Of_Secondary_Eductaion_
# True
