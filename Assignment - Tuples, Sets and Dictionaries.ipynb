# %% [markdown]
# ## <u>While doing this assignment only use those concepts which have been taught till now</u>

# %% [markdown]
# ## <u>Problem 1</u>
#
# ### Another measure of average
#
# * Mode is defined as the value that appears most often in a set of data values. Mode corresponds to the most frequent value.
# * You are given a list of numbers and you need to calculate the mode of this list

# %%
# A list containing average daily temperature over 10 days
temperatures = [34, 40, 29, 33, 42, 40, 39, 34, 34,33 ]

# %%
# Step 1 : Find the unique set of values. Store this in a list
unique_temperatures = list(set(temperatures))

# %%
# Print the unique temperature list
print(unique_temperatures)
# Out:
# [33, 34, 39, 40, 42, 29]

# %%
# Step 2 : Create an empty dictionary which will contain the unique temperatures as keys and their counts in the original temperatures list as values
temp_count={}

# Set the values for each key separately
# First key
key_one=unique_temperatures[0]
value_one= temperatures.count(key_one)
print(key_one)
print(value_one)
# Second key
key_two=unique_temperatures[1]
value_two= temperatures.count(key_two)
print(key_two)
print(value_two)
# Third key
key_three=unique_temperatures[2]
value_three= temperatures.count(key_three)
print(key_three)
print(value_three)
# Fourth key
key_four=unique_temperatures[3]
value_four= temperatures.count(key_four)
print(key_four)
print(value_four)


# Fifth key
key_five=unique_temperatures[4]
value_five= temperatures.count(key_five)
print(key_five)
print(value_five)


# Sixth key
key_six=unique_temperatures[5]
value_six= temperatures.count(key_six)
print(key_six)
print(value_six)
# Out:
# 33
# 2
# 34
# 3
# 39
# 1
# 40
# 2
# 42
# 1
# 29
# 1

# %%
# Step 3: Store the dictionary values in a list
temp_dict_frequencies = {key_one:value_one,key_two:value_two,key_three:value_three,key_four:value_four,key_five:value_five,key_six:value_six}
type(temp_dict_frequencies)
# Print the list of dictionary values
# print(temp_dict_frequencies)
new_key=list(temp_dict_frequencies.keys())
new_val=list(temp_dict_frequencies.values())
print(new_key)
print(new_val)
print(type(new_key))
print(type(new_val))

# Find the index of the most frequent temperature value
max_val=max(new_val)
print(max_val)
#printing index of max occured value
index= new_val.index(max_val)
print(index)
# Out:
# [33, 34, 39, 40, 42, 29]
# [2, 3, 1, 2, 1, 1]
# <class 'list'>
# <class 'list'>
# 3
# 1

# %%
# Step 4 : Create the list of dictionary keys
temp_dict_keys = list(temp_dict_frequencies.values())

# Print the list of dictionary keys
print(temp_dict_keys)

# Calculate the mode temperature
# mode_temp =
# Out:
# [2, 3, 1, 2, 1, 1]

# %% [markdown]
# ## <u>Problem 2 </u>
#
# ### Challenging the immutability of tuples
#
# You are given a list of tuples. You need to replace the last element of the last tuple

# %%
# Input list of tuples

list_of_tuples = [(10,20,30),(30,40,50),(50,60,70)]

print(type(list_of_tuples))

# Expected output : Replace the last element 70 with 100
# output_list = [(10,20,30),(30,40,50),(50,60,100)]
# Out:
# <class 'list'>

# %%
# Your code here 
last_element= list_of_tuples[-1][:-1] + (100,)
output_list =list_of_tuples[:-1]
output_list.append(last_element)
list_of_tuples=output_list





# Print the output list
print(list_of_tuples)
# Out:
# [(10, 20, 30), (30, 40, 50), (50, 60, 100)]

# %% [markdown]
# ## <u> Problem 3 </u>
#
# Natural Language Processing or NLP is one of the most promising fields in Machine Learning. Most of the times in NLP we deal with the textual data (a bunch of strings). Sometimes when we are processing the text, it is a common practice to get rid of some set of stop words from our original text. By default stop words are very common words used in English language such as and, or, punctuations etc.
#
# In this exercise, you are provided with a default set of stop words and you need to add some extra set of custom words.

# %%
# A sample sentence 

sentence = 'Hello, good morning folks! Today we will announce the half yearly performance results of the company. Due to the ongoing COVID-19 pandemic, our profits have declined by 60% as compared to the last half yearly results'

# Print your sentence
print(sentence)
# Out:
# Hello, good morning folks! Today we will announce the half yearly performance results of the company. Due to the ongoing COVID-19 pandemic, our profits have declined by 60% as compared to the last half yearly results

# %%
# Default set of stop words 
stop_words = {"i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", 
              "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself",
              "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that",
              "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had",
              "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because",
              "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into",
              "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", 
              "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where",
              "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no",
              "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just",
              "don", "should", "now"}

type(stop_words)              
print(stop_words)
print(len(stop_words))
# Out:
# {'will', 's', 'there', 'into', 'being', 'was', 'same', 'have', 'had', 'at', 'after', 'if', 'no', 'some', 'those', 'having', 'theirs', 'only', 'off', 'between', 'yourselves', 'we', 'their', 'each', 'should', 'ourselves', 'its', 'a', 'and', 'over', 'are', 'don', 'because', 'your', 'did', 'how', 'again', 'all', 'now', 'before', 'doing', 'than', 'few', 'this', 'here', 'myself', 'not', 'an', 'up', 'it', 'to', 'i', 'is', 'once', 'his', 'own', 'both', 'these', 'below', 'so', 'himself', 'while', 'my', 'from', 'yourself', 'that', 'the', 'herself', 'until', 'nor', 'which', 'yours', 'be', 'who', 'does', 'further', 'been', 'any', 'too', 'do', 'whom', 'just', 'where', 'during', 'ours', 'of', 'on', 'such', 'has', 'through', 'by', 'or', 'itself', 'me', 'she', 'more', 'out', 'for', 'very', 'our', 'they', 'her', 'them', 'themselves', 'then', 'hers', 'why', 'under', 'he', 'as', 'what', 'him', 'you', 'in', 'with', 'above', 'against', 'can', 'were', 'other', 'but', 'most', 'down', 'am', 'when', 'about', 't'}
# 127

# %%
# Update the set of stop words by adding the custom stop words
custom_stop_words = ["hello","good","morning","half","yearly"]

# Your code here
stop_words.update(custom_stop_words)

# Print the updated stop words
print(stop_words)
print(len(stop_words))
# Out:
# {'will', 's', 'there', 'into', 'being', 'was', 'same', 'have', 'had', 'at', 'after', 'if', 'no', 'some', 'those', 'having', 'theirs', 'only', 'off', 'between', 'yourselves', 'we', 'their', 'each', 'good', 'should', 'ourselves', 'its', 'a', 'and', 'over', 'are', 'don', 'because', 'your', 'did', 'how', 'again', 'all', 'now', 'before', 'doing', 'half', 'than', 'few', 'this', 'here', 'myself', 'not', 'an', 'morning', 'up', 'it', 'to', 'i', 'is', 'once', 'his', 'own', 'both', 'these', 'below', 'so', 'himself', 'while', 'my', 'from', 'yourself', 'that', 'the', 'herself', 'until', 'nor', 'which', 'yours', 'be', 'who', 'yearly', 'does', 'further', 'been', 'any', 'too', 'do', 'whom', 'just', 'where', 'during', 'ours', 'of', 'on', 'such', 'has', 'through', 'by', 'or', 'itself', 'me', ('hello', 'good', 'morning', 'half', 'yearly'), 'she', 'more', 'out', 'for', 'very', 'our', 'they', 'her', 'hello', 'them', 'themselves', 'then', 'hers', 'why', 'under', 'he', 'as', 'what', 'him', 'you', 'in', 'with', 'above', 'against', 'can', 'were', 'other', 'but', 'most', 'down', 'am', 'when', 'about', 't'}
# 133

# %%
# Do the same task another way. Keep in mind to use the original set of stop_words for this piece of code
custom_stop_words = ["hello","good","morning","half","yearly"]

stop_words.add(tuple(custom_stop_words))

# Print the updated stop words
print(stop_words)
print(len(stop_words))
# Out:
# {'will', 's', 'there', 'into', 'being', 'was', 'same', 'have', 'had', 'at', 'after', 'if', 'no', 'some', 'those', 'having', 'theirs', 'only', 'off', 'between', 'yourselves', 'we', 'their', 'each', 'should', 'ourselves', 'its', 'a', 'and', 'over', 'are', 'don', 'because', 'your', 'did', 'how', 'again', 'all', 'now', 'before', 'doing', 'than', 'few', 'this', 'here', 'myself', 'not', 'an', 'up', 'it', 'to', 'i', 'is', 'once', 'his', 'own', 'both', 'these', 'below', 'so', 'himself', 'while', 'my', 'from', 'yourself', 'that', 'the', 'herself', 'until', 'nor', 'which', 'yours', 'be', 'who', 'does', 'further', 'been', 'any', 'too', 'do', 'whom', 'just', 'where', 'during', 'ours', 'of', 'on', 'such', 'has', 'through', 'by', 'or', 'itself', 'me', ('hello', 'good', 'morning', 'half', 'yearly'), 'she', 'more', 'out', 'for', 'very', 'our', 'they', 'her', 'them', 'themselves', 'then', 'hers', 'why', 'under', 'he', 'as', 'what', 'him', 'you', 'in', 'with', 'above', 'against', 'can', 'were', 'other', 'but', 'most', 'down', 'am', 'when', 'about', 't'}
# 128

# %% [markdown]
# ## <u>Problem 4</u>
#
#  Write a Python script to check whether a given key already exists in a dictionary. If it does, drop that key from the dictionary. If it does not, add that key and corresponding value to the dictionary

# %%
# Your dictionary
employee_dict = {'Name':'Sanket','Skills':['Python','Machine Learning','Deep Learning'],'Band':6.0,
                 'Promotion Year':[2016,2018,2020]}

# %%
# Check if the key 'Employee_ID' is present in the dictionary. Hint : use a boolean variable to store this value


# If not present add this key to this dictionary and the corresponding value to be 4503233

# %%
# Check if the key 'Band' is present in the dictionary.


# If present, drop this key from the dictionary

# %%
# Print the updated dictionary
