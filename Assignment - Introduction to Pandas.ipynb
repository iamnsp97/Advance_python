# %% [markdown]
# # <u> Use only those concepts which have been taught till now </u>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # <u>**Problem 1**</u>
#
# ### You are given a list of urls. You need to extract the domain name from the urls in another list. Also you need to extract the ending string which the url ends with.
#
# ### For example, https://www.example.com/market.php -- In this example, domain name is <code>www.example.com</code> and the ending string is <code>php</code>

# %%
from urllib.parse import urlparse

def extract_domain_and_ending(urls):
    extracted_data = []
    for url in urls:
        parsed_url = urlparse(url)
        domain = parsed_url.netloc
        ending = parsed_url.path.split('/')[-1]
        extracted_data.append((domain, ending))
    return extracted_data

url_list = [
    'https://blog.hubspot.com/marketing/parts-url',
    'https://www.almabetter.com/enrollments',
    'https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html',
    'https://www.programiz.com/python-programming/list'
]

extracted_data = extract_domain_and_ending(url_list)
for domain, ending in extracted_data:
    print("Domain:", domain)
    print("Ending:", ending)
    print()
# Out:
# Domain: blog.hubspot.com
# Ending: parts-url
#
# Domain: www.almabetter.com
# Ending: enrollments
#
# Domain: pandas.pydata.org
# Ending: pandas.DataFrame.rename.html
#
# Domain: www.programiz.com
# Ending: list

# %% [markdown]
# ## Next create a pandas dataframe with the above three lists.

# %%
import pandas as pd

# Extracted data from URLs
domains = ['blog.hubspot.com', 'www.almabetter.com', 'pandas.pydata.org', 'www.programiz.com']
endings = ['parts-url', 'enrollments', 'pandas.DataFrame.rename.html', 'list']

# Create DataFrame
data = list(zip(domains, endings))
df = pd.DataFrame(data, columns=['Domain', 'Ending'])

# Print the DataFrame
print(df)
# Out:
#                Domain                        Ending
# 0    blog.hubspot.com                     parts-url
# 1  www.almabetter.com                   enrollments
# 2   pandas.pydata.org  pandas.DataFrame.rename.html
# 3   www.programiz.com                          list
