# %%
my_tuple=(1,'a',3)

# %%
print(my_tuple)
# Out:
# (1, 'a', 3)

# %%
type(my_tuple)
# Out:
# tuple

# %%
another_tuple=('one',2,4.53,'asbc')

print(another_tuple)
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
my_list=[1]

# %%
type(my_list)
# Out:
# list

# %%
my_tuple=(1,)
type(my_tuple)
# Out:
# tuple

# %%
my_tuple=(1,2,3,4)

# %%
len(my_tuple)
# Out:
# 4

# %%
print(another_tuple)
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
print(another_tuple[0])
# Out:
# one

# %%
print(another_tuple[3])
# Out:
# asbc

# %%
print(another_tuple[-1])
# Out:
# asbc

# %%
another_tuple[-1]
# Out:
# 'asbc'

# %%
another_tuple[-3]
# Out:
# 2

# %%
print(another_tuple)
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
another_tuple[1:3]
# Out:
# (2, 4.53)

# %%
another_tuple[2:]
# Out:
# (4.53, 'asbc')

# %%
another_tuple[:6]
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
another_tuple[-4:]
# Out:
# ('one', 2, 4.53, 'asbc')

# %%
another_tuple[::-1]
# Out:
# ('asbc', 4.53, 2, 'one')

# %%
random_tuple=(1,5,6,2)

# %%
sorted(random_tuple)
# Out:
# [1, 2, 5, 6]

# %%
my_tuple=(1,2,3,4,5,6,1,1,2)

# %%
my_tuple.index(2)
# Out:
# 1

# %%
my_tuple.count(2)
# Out:
# 2

# %%
my_tuple.count(1)
# Out:
# 3

# %%
my_list=[1,2,3,4]

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %%
print(my_tuple)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 1, 2)

# %%
print(my_tuple[0])
# Out:
# 1

# %%
my_tuple[0]='change'
my_tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-cda9473105e6> in <module>
# ----> 1 my_tuple[0]='change'
#       2 my_tuple
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_list=[5,7,9,3,2]

# %%
my_list[0]=1

# %%
my_list
# Out:
# [1, 7, 9, 3, 2]

# %%
city_list = ['Delhi','Patna','Cuttack','Guwahati']
river_list = ['Yamuna','Ganga','Mahanadi','Brahmaputra']

# %%
city_and_their_rivers=list(zip(city_list,river_list))

# %%
city_and_their_rivers
# Out:
# [('Delhi', 'Yamuna'),
#  ('Patna', 'Ganga'),
#  ('Cuttack', 'Mahanadi'),
#  ('Guwahati', 'Brahmaputra')]

# %%
empty_set = set()

# %%
type(empty_set)
# Out:
# set

# %%
non_empty_set = {1,6,4,'abc'}

# %%
type(non_empty_set)
# Out:
# set

# %%
my_object = {}

# %%
type(my_object)
# Out:
# dict

# %%
my_set = set()

# %%
type(my_set)
# Out:
# set

# %%
my_list = [1,1,2,2,3,4,5,6,1,1]

# %%
my_set = set(my_list)

# %%
my_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_set={1,2,(2,3)}

# %%
my_set={1,2,{3,5}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-74f7ffba25a5> in <module>
# ----> 1 my_set={1,2,{3,5}}
#
# TypeError: unhashable type: 'set'

# %%
my_set = set()
my_set.add('a')

# %%
my_set
# Out:
# {'a'}

# %%
my_set.add(2)

# %%
print(my_set)
# Out:
# {'a', 2}

# %%
my_set.add(1)
print(my_set)
# Out:
# {'a', 1, 2}

# %%
my_set.add(1)
print(my_set)
# Out:
# {'a', 1, 2}

# %%
my_set.update([5,6,7,8])
print(my_set)
# Out:
# {'a', 1, 2, 5, 6, 7, 8}

# %%
my_set.remove(6)

# %%
print(my_set)
# Out:
# {'a', 1, 2, 5, 7, 8}

# %%
A= {1,2,3,4,5}
B= {4,5,6,7,8}
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
A | B
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
A.intersection(B)
# Out:
# {4, 5}

# %%
A.difference(B)
# Out:
# {1, 2, 3}

# %%
A-B
# Out:
# {1, 2, 3}

# %%
B.difference(A)
# Out:
# {6, 7, 8}

# %%
B - A
# Out:
# {6, 7, 8}

# %%
A.symmetric_difference(B)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
A^B
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
marvel_dict ={'Name':'Thor','Place':'Asgard','Weapon' : 'Hammer', 1:2, 3 : 'power', 'alibies' : ['Ironman','Captain America'], 'abc' : {1:2, 4:5}}

# %%
marvel_dict['Place']
# Out:
# 'Asgard'

# %%
type(marvel_dict)
# Out:
# dict

# %%
marvel_dict['Random']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-9f68b85bbfcd> in <module>
# ----> 1 marvel_dict['Random']
#
# KeyError: 'Random'

# %%
marvel_dict['Weapon']
# Out:
# 'Hammer'

# %%
marvel_dict['alibies']
# Out:
# ['Ironman', 'Captain America']

# %%
type(marvel_dict['abc'])
# Out:
# dict

# %%
marvel_dict.keys()
# Out:
# dict_keys(['Name', 'Place', 'Weapon', 1, 3, 'alibies', 'abc'])

# %%
marvel_dict.get('Place')
# Out:
# 'Asgard'

# %%
marvel_dict.get('Random')

# %%
marvel_dict.get('Random','Not Fou')
# Out:
# 'Not Found'
